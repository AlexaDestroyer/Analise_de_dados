# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexaDestroyer/Analise_de_dados/blob/main/Caracter%C3%ADsticas_de_vinhos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Qualidade dos Vinhos 🍷
# A análise se refere a Dados dedos Vinhos Tinto e Branco tirado de um dataset público,fonte citada célula abaixo, contendo 12 características **químicas** e **sensoriais** para avaliação da qualidade de um vinho, são elas:
#
# Características **Sensoriais**
# **Acidez fixa:** Refere-se à acidez natural do vinho, proveniente principalmente do ácido tartárico e málico das uvas. Níveis mais altos de acidez fixa contribuem para a frescor e vivacidade do vinho, enquanto níveis mais baixos podem resultar em um vinho mais macio e redondo.
# **Acidez volátil**: É a parte da acidez do vinho derivada de compostos voláteis como ácido acético e ácido etanoico. Níveis elevados de acidez volátil podem indicar um vinho estragado ou com defeito, enquanto níveis moderados podem agregar complexidade e interesse ao vinho.
# **Ácido cítrico**: Um dos principais ácidos orgânicos do vinho, o ácido cítrico contribui para a acidez e o sabor cítrico do vinho. Níveis equilibrados de ácido cítrico conferem frescor e vivacidade, enquanto níveis excessivos podem resultar em um vinho azedo.
# **Açúcar residual**: Refere-se à quantidade de açúcar não fermentado que permanece no vinho após a fermentação. Vinhos secos têm baixo teor de açúcar residual, enquanto vinhos doces, como os Portos, podem ter um teor de açúcar residual significante.
# **Cloretos**: Presentes em pequenas quantidades no vinho, os cloretos podem contribuir para o sabor salgado ou mineral do vinho. Níveis excessivos de cloretos podem indicar um problema de produção.
# **Dióxido de enxofre livre**: Um conservante adicionado ao vinho para prevenir a oxidação e o crescimento microbiano. Níveis moderados de dióxido de enxofre livre são geralmente aceitáveis, enquanto níveis excessivos podem ter um sabor amargo ou pungente.
# **Dióxido de enxofre total**: A soma do dióxido de enxofre livre e do dióxido de enxofre ligado, este último formado durante a fermentação. Níveis mais altos de dióxido de enxofre total podem indicar um vinho com maior potencial de oxidação.
# **Densidade**: Indica a massa do vinho por unidade de volume. Vinhos com maior densidade geralmente têm maior teor de álcool, extrato e corpo.
# **PH:** Uma medida da acidez ou alcalinidade do vinho. Níveis de pH mais baixos indicam um vinho mais ácido, enquanto níveis de pH mais altos indicam um vinho mais alcalino. O pH ideal para o vinho varia de acordo com o estilo e a variedade da uva.
# **Sulfatos**: Presentes em pequenas quantidades no vinho, os sulfatos podem contribuir para o sabor salgado ou mineral do vinho. Níveis excessivos de sulfatos podem indicar um problema de produção.
# **Teor alcoólico**: A porcentagem de álcool etílico presente no vinho. O teor alcoólico varia de acordo com a variedade da uva, o clima e as práticas de vinificação.
#
# Características Sensoriais:
# **Qualidade**: Uma avaliação geral da qualidade do vinho, levando em consideração suas características organolépticas, como aparência, aroma, sabor e final de boca.

# %% [markdown]
# ## **Dados Coletados**

# %%
#Fontes:https://www.kaggle.com/datasets/uciml/red-wine-quality-cortez-et-al-2009/code' / #https://www.kaggle.com/datasets/piyushagni5/white-wine-quality

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

#Variaveis
dados_tinto = pd.read_csv('/content/winequality-red.csv')

dados_branco = pd.read_csv('/content/winequality-white.csv', sep = ';', decimal=',', encoding= 'UTF-8')

# %% [markdown]
# ## **Exploração e limpeza dos Dados**
# Rastreio de inconsistências, valores ausentes, erros ou outliers.

# %%
dados_tinto.head()   #VINHO TINTO
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
dados_branco.head()
# Out:
#   fixed acidity volatile acidity citric acid residual sugar chlorides  \
# 0             7             0.27        0.36           20.7     0.045
# 1           6.3              0.3        0.34            1.6     0.049
# 2           8.1             0.28         0.4            6.9      0.05
# 3           7.2             0.23        0.32            8.5     0.058
# 4           7.2             0.23        0.32            8.5     0.058
#
#   free sulfur dioxide total sulfur dioxide density    pH sulphates alcohol  \
# 0                  45                  170   1.001     3      0.45     8.8
# 1                  14                  132   0.994   3.3      0.49     9.5
# 2                  30                   97  0.9951  3.26      0.44    10.1
# 3                  47                  186  0.9956  3.19       0.4     9.9
# 4                  47                  186  0.9956  3.19       0.4     9.9
#
#    quality
# 0        6
# 1        6
# 2        6
# 3        6
# 4        6

# %%
dados_tinto.info()  #VINHO TINTO
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
dados_branco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   object
#  1   volatile acidity      4898 non-null   object
#  2   citric acid           4898 non-null   object
#  3   residual sugar        4898 non-null   object
#  4   chlorides             4898 non-null   object
#  5   free sulfur dioxide   4898 non-null   object
#  6   total sulfur dioxide  4898 non-null   object
#  7   density               4898 non-null   object
#  8   pH                    4898 non-null   object
#  9   sulphates             4898 non-null   object
#  10  alcohol               4898 non-null   object
#  11  quality               4898 non-null   int64
# dtypes: int64(1), object(11)
# memory usage: 459.3+ KB

# %%
dados_tinto.dtypes  #VINHO TINTO
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
dados_branco.dtypes
# *em describe() dados em obj foram convertidos para Float
# Out:
# fixed acidity           object
# volatile acidity        object
# citric acid             object
# residual sugar          object
# chlorides               object
# free sulfur dioxide     object
# total sulfur dioxide    object
# density                 object
# pH                      object
# sulphates               object
# alcohol                 object
# quality                  int64
# dtype: object

# %%
dados_tinto.columns  #VINHO TINTO
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
dados_branco.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
#Renomeando/ traduzindo as colunas do Tinto  #VINHO TINTO
colunas_originais_tinto = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
                    'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
                    'pH', 'sulphates', 'alcohol', 'quality']

colunas_traduzidas_tinto = {'fixed acidity': 'acidez fixa',  'volatile acidity': 'acidez volátil', 'citric acid': 'ácido cítrico',  'residual sugar': 'açúcar residual',  'chlorides': 'cloretos', 'free sulfur dioxide': 'enxofre livre (dióxido)',  'total sulfur dioxide': 'enxofre total (dióxido)',  'density': 'densidade',  'pH': 'PH', 'alcohol': 'álcool', 'quality': 'qualidade'}

dados_tinto.rename(columns= colunas_traduzidas_tinto, inplace=True)

# %%
dados_tinto.columns #colunas em portugues  #VINHO TINTO
# Out:
# Index(['acidez fixa', 'acidez volátil', 'ácido cítrico', 'açúcar residual',
#        'cloretos', 'enxofre livre (dióxido)', 'enxofre total (dióxido)',
#        'densidade', 'PH', 'sulphates', 'álcool', 'qualidade'],
#       dtype='object')

# %%
#Renomeando/ traduzindo as colunas do Branco
colunas_originais_branco = {'fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar','chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density','pH', 'sulphates', 'alcohol', 'quality'}

colunas_traduzidas_branco = {'fixed acidity': 'acidez fixa',  'volatile acidity': 'acidez volátil', 'citric acid': 'ácido cítrico',  'residual sugar': 'açúcar residual',  'chlorides': 'cloretos', 'free sulfur dioxide': 'enxofre livre (dióxido)',  'total sulfur dioxide': 'enxofre total (dióxido)',  'density': 'densidade',  'pH': 'PH', 'alcohol': 'álcool', 'quality': 'qualidade'}

dados_branco.rename(columns= colunas_traduzidas_branco, inplace=True)

# %%
dados_branco.columns
# Out:
# Index(['acidez fixa', 'acidez volátil', 'ácido cítrico', 'açúcar residual',
#        'cloretos', 'enxofre livre (dióxido)', 'enxofre total (dióxido)',
#        'densidade', 'PH', 'sulphates', 'álcool', 'qualidade'],
#       dtype='object')

# %%
dados_branco.head()
# Out:
#   acidez fixa acidez volátil ácido cítrico açúcar residual cloretos  \
# 0           7           0.27          0.36            20.7    0.045
# 1         6.3            0.3          0.34             1.6    0.049
# 2         8.1           0.28           0.4             6.9     0.05
# 3         7.2           0.23          0.32             8.5    0.058
# 4         7.2           0.23          0.32             8.5    0.058
#
#   enxofre livre (dióxido) enxofre total (dióxido) densidade    PH sulphates  \
# 0                      45                     170     1.001     3      0.45
# 1                      14                     132     0.994   3.3      0.49
# 2                      30                      97    0.9951  3.26      0.44
# 3                      47                     186    0.9956  3.19       0.4
# 4                      47                     186    0.9956  3.19       0.4
#
#   álcool  qualidade
# 0    8.8          6
# 1    9.5          6
# 2   10.1          6
# ...

# %%
#Conversão de obj para Float
convertido = dados_branco.columns
for col in convertido:
     dados_branco[col] = pd.to_numeric(dados_branco[col], errors='coerce')
print(dados_branco.dtypes)
# Out:
# acidez fixa                float64
# acidez volátil             float64
# ácido cítrico              float64
# açúcar residual            float64
# cloretos                   float64
# enxofre livre (dióxido)    float64
# enxofre total (dióxido)    float64
# densidade                  float64
# PH                         float64
# sulphates                  float64
# álcool                     float64
# qualidade                    int64
# dtype: object

# %%
dados_tinto.isnull().sum() #VINHO TINTO
# Out:
# acidez fixa                0
# acidez volátil             0
# ácido cítrico              0
# açúcar residual            0
# cloretos                   0
# enxofre livre (dióxido)    0
# enxofre total (dióxido)    0
# densidade                  0
# PH                         0
# sulphates                  0
# álcool                     0
# qualidade                  0
# dtype: int64

# %%
dados_branco.isnull().sum()
# Out:
# acidez fixa                0
# acidez volátil             0
# ácido cítrico              0
# açúcar residual            0
# cloretos                   0
# enxofre livre (dióxido)    0
# enxofre total (dióxido)    0
# densidade                  0
# PH                         0
# sulphates                  0
# álcool                     0
# qualidade                  0
# dtype: int64

# %%
# Remover linhas com valores ausentes - #VINHO TINTO
df_sem_valores_ausentes = dados_tinto.dropna()
df_sem_valores_ausentes.head()
# Out:
#    acidez fixa  acidez volátil  ácido cítrico  açúcar residual  cloretos  \
# 0          7.4            0.70           0.00              1.9     0.076
# 1          7.8            0.88           0.00              2.6     0.098
# 2          7.8            0.76           0.04              2.3     0.092
# 3         11.2            0.28           0.56              1.9     0.075
# 4          7.4            0.70           0.00              1.9     0.076
#
#    enxofre livre (dióxido)  enxofre total (dióxido)  densidade    PH  \
# 0                     11.0                     34.0     0.9978  3.51
# 1                     25.0                     67.0     0.9968  3.20
# 2                     15.0                     54.0     0.9970  3.26
# 3                     17.0                     60.0     0.9980  3.16
# 4                     11.0                     34.0     0.9978  3.51
#
#    sulphates  álcool  qualidade
# 0       0.56     9.4          5
# 1       0.68     9.8          5
# ...

# %%
# Remover linhas com valores ausentes - BRANCO
df_sem_valores_ausentes = dados_branco.dropna()
df_sem_valores_ausentes.head()
# Out:
#    acidez fixa  acidez volátil  ácido cítrico  açúcar residual  cloretos  \
# 0          7.0            0.27           0.36             20.7     0.045
# 1          6.3            0.30           0.34              1.6     0.049
# 2          8.1            0.28           0.40              6.9     0.050
# 3          7.2            0.23           0.32              8.5     0.058
# 4          7.2            0.23           0.32              8.5     0.058
#
#    enxofre livre (dióxido)  enxofre total (dióxido)  densidade    PH  \
# 0                     45.0                    170.0     1.0010  3.00
# 1                     14.0                    132.0     0.9940  3.30
# 2                     30.0                     97.0     0.9951  3.26
# 3                     47.0                    186.0     0.9956  3.19
# 4                     47.0                    186.0     0.9956  3.19
#
#    sulphates  álcool  qualidade
# 0       0.45     8.8          6
# 1       0.49     9.5          6
# ...

# %%
dados_tinto.nunique() #VINHO TINTO
# Out:
# acidez fixa                 96
# acidez volátil             143
# ácido cítrico               80
# açúcar residual             91
# cloretos                   153
# enxofre livre (dióxido)     60
# enxofre total (dióxido)    144
# densidade                  436
# PH                          89
# sulphates                   96
# álcool                      65
# qualidade                    6
# dtype: int64

# %%
dados_branco.nunique()
# Out:
# acidez fixa                 68
# acidez volátil             125
# ácido cítrico               87
# açúcar residual            310
# cloretos                   160
# enxofre livre (dióxido)    132
# enxofre total (dióxido)    251
# densidade                  890
# PH                         103
# sulphates                   79
# álcool                     103
# qualidade                    7
# dtype: int64

# %%
# Filtrar colunas que têm mais de um valor único - #VINHO TINTO
colunas_relevantes = [col for col in dados_tinto.columns if dados_tinto[col].nunique() > 1]
dados_relevante = dados_tinto[colunas_relevantes]
dados_relevante.head()
# Out:
#    acidez fixa  acidez volátil  ácido cítrico  açúcar residual  cloretos  \
# 0          7.4            0.70           0.00              1.9     0.076
# 1          7.8            0.88           0.00              2.6     0.098
# 2          7.8            0.76           0.04              2.3     0.092
# 3         11.2            0.28           0.56              1.9     0.075
# 4          7.4            0.70           0.00              1.9     0.076
#
#    enxofre livre (dióxido)  enxofre total (dióxido)  densidade    PH  \
# 0                     11.0                     34.0     0.9978  3.51
# 1                     25.0                     67.0     0.9968  3.20
# 2                     15.0                     54.0     0.9970  3.26
# 3                     17.0                     60.0     0.9980  3.16
# 4                     11.0                     34.0     0.9978  3.51
#
#    sulphates  álcool  qualidade
# 0       0.56     9.4          5
# 1       0.68     9.8          5
# ...

# %%
# Filtrar colunas que têm mais de um valor único - BRANCO
colunas_relevantes = [col for col in dados_branco.columns if dados_branco[col].nunique() > 1]
dados_relevante = dados_branco[colunas_relevantes]
dados_relevante.head()
# Out:
#    acidez fixa  acidez volátil  ácido cítrico  açúcar residual  cloretos  \
# 0          7.0            0.27           0.36             20.7     0.045
# 1          6.3            0.30           0.34              1.6     0.049
# 2          8.1            0.28           0.40              6.9     0.050
# 3          7.2            0.23           0.32              8.5     0.058
# 4          7.2            0.23           0.32              8.5     0.058
#
#    enxofre livre (dióxido)  enxofre total (dióxido)  densidade    PH  \
# 0                     45.0                    170.0     1.0010  3.00
# 1                     14.0                    132.0     0.9940  3.30
# 2                     30.0                     97.0     0.9951  3.26
# 3                     47.0                    186.0     0.9956  3.19
# 4                     47.0                    186.0     0.9956  3.19
#
#    sulphates  álcool  qualidade
# 0       0.45     8.8          6
# 1       0.49     9.5          6
# ...

# %%
dados_tinto['qualidade'].value_counts()    #VINHO TINTO
# Out:
# qualidade
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
dados_branco['qualidade'].value_counts()
# Out:
# qualidade
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %% [markdown]
# **Análise Explolatória**
# Identificação de Padrões, tendencias e correlações

# %% [markdown]
# ### **Características em numeros e medidas:**
#
# **Acidez fixa**: Quantidade de ácido tartárico no vinho (g/dm³).
# **Acidez volátil**: Quantidade de ácido acético no vinho (g/dm³).
# **Ácido cítrico**: Quantidade de ácido cítrico no vinho (g/dm³).
# **Açúcar residual**: Quantidade de açúcar restante após a fermentação (g/dm³).
# **Cloretos**: Quantidade de sal no vinho (g/dm³).
# **Enxofre livre **(dióxido): Quantidade de dióxido de enxofre livre no vinho (mg/dm³).
# **Enxofre total (dióxido)**: Quantidade total de dióxido de enxofre no vinho (mg/dm³).
# **Densidade**: Densidade do vinho (g/cm³).
# **PH**: Nível de acidez/alcalinidade do vinho.
# **Sulfatos**: Quantidade de sulfatos adicionados ao vinho (g/dm³).
# **Álcool**: Teor alcoólico do vinho (% em volume).
# **Qualidade**: Qualidade do vinho, classificada em uma escala de 0 a 10, com 0 sendo o pior e 10 o melhor.

# %%
print(dados_branco.describe(include='all'))
# Out:
#        acidez fixa  acidez volátil  ácido cítrico  açúcar residual  \
# count  4898.000000     4898.000000    4898.000000      4898.000000
# mean      6.854788        0.278241       0.334192         6.391415
# std       0.843868        0.100795       0.121020         5.072058
# min       3.800000        0.080000       0.000000         0.600000
# 25%       6.300000        0.210000       0.270000         1.700000
# 50%       6.800000        0.260000       0.320000         5.200000
# 75%       7.300000        0.320000       0.390000         9.900000
# max      14.200000        1.100000       1.660000        65.800000
#
#           cloretos  enxofre livre (dióxido)  enxofre total (dióxido)  \
# count  4898.000000              4898.000000              4898.000000
# mean      0.045772                35.308085               138.360657
# std       0.021848                17.007137                42.498065
# min       0.009000                 2.000000                 9.000000
# ...

# %%
print(dados_tinto.describe(include='all'))   #VINHO TINTO
# Out:
#        acidez fixa  acidez volátil  ácido cítrico  açúcar residual  \
# count  1599.000000     1599.000000    1599.000000      1599.000000
# mean      8.319637        0.527821       0.270976         2.538806
# std       1.741096        0.179060       0.194801         1.409928
# min       4.600000        0.120000       0.000000         0.900000
# 25%       7.100000        0.390000       0.090000         1.900000
# 50%       7.900000        0.520000       0.260000         2.200000
# 75%       9.200000        0.640000       0.420000         2.600000
# max      15.900000        1.580000       1.000000        15.500000
#
#           cloretos  enxofre livre (dióxido)  enxofre total (dióxido)  \
# count  1599.000000              1599.000000              1599.000000
# mean      0.087467                15.874922                46.467792
# std       0.047065                10.460157                32.895324
# min       0.012000                 1.000000                 6.000000
# ...

# %%
#variança e Desvio padrão
print(dados_branco.var())
print(dados_branco.std())
# Out:
# acidez fixa                   0.712114
# acidez volátil                0.010160
# ácido cítrico                 0.014646
# açúcar residual              25.725770
# cloretos                      0.000477
# enxofre livre (dióxido)     289.242720
# enxofre total (dióxido)    1806.085491
# densidade                     0.000009
# PH                            0.022801
# sulphates                     0.013025
# álcool                        1.514427
# qualidade                     0.784356
# dtype: float64
# acidez fixa                 0.843868
# acidez volátil              0.100795
# ácido cítrico               0.121020
# açúcar residual             5.072058
# cloretos                    0.021848
# enxofre livre (dióxido)    17.007137
# enxofre total (dióxido)    42.498065
# densidade                   0.002991
# PH                          0.151001
# sulphates                   0.114126
# álcool                      1.230621
# qualidade                   0.885639
# dtype: float64

# %%
print(dados_tinto.var())   #VINHO TINTO
print(dados_tinto.std())
# Out:
# acidez fixa                   3.031416
# acidez volátil                0.032062
# ácido cítrico                 0.037947
# açúcar residual               1.987897
# cloretos                      0.002215
# enxofre livre (dióxido)     109.414884
# enxofre total (dióxido)    1082.102373
# densidade                     0.000004
# PH                            0.023835
# sulphates                     0.028733
# álcool                        1.135647
# qualidade                     0.652168
# dtype: float64
# acidez fixa                 1.741096
# acidez volátil              0.179060
# ácido cítrico               0.194801
# açúcar residual             1.409928
# cloretos                    0.047065
# enxofre livre (dióxido)    10.460157
# enxofre total (dióxido)    32.895324
# densidade                   0.001887
# PH                          0.154386
# sulphates                   0.169507
# álcool                      1.065668
# qualidade                   0.807569
# dtype: float64

# %% [markdown]
# **Visualização dos Dados**

# %%
#Visualização das colunas - VINHO TINTO
plt.figure(figsize=(8, 6))
sns.histplot(dados_tinto['qualidade'], bins=range(1, 11), kde=False, color='lightcoral', edgecolor='black')
plt.xlabel('Qualidade')
plt.ylabel('Frequência')
plt.title(' Qualidade do Vinho Tinto')
plt.grid(True)
plt.show()

# %%
#Visualização das colunas - VINHO BRANCO
plt.figure(figsize=(8, 6))
sns.histplot(dados_branco['qualidade'], bins=range(1, 11), kde=False, color='lightgreen', edgecolor='black')
plt.xlabel('Qualidade')
plt.ylabel('Frequência')
plt.title(' Qualidade do Vinho Branco')
plt.grid(True)
plt.show()

#-------------------------------------------------------CONCLUSÃO------------------------------------------------------------------------------------
# VINHO TINTO : atinge seu apice de QUALIDADE entre a SCALA DE 5 a 6 com a FREQUENCIA MAXIMA 700.Sendo as outras scalas inferiores ao resultado.
# VINHO BRANCO : atinge seu apice de QUALIDADE entre a SCALA DE 6 a 7 com a FREQUENCIA MAXIMA acima de 2000.Sendo as outras scalas inferiores ao resultado.
#Tanto no vinho TINTO quanto no vinho BRANCO a caracteristica QUALIDADE é encontrada em poucas scalas o que pode ser uma variavel com caracteristicas de clara desprorpoção.

# %%
# Visualização da matriz de correlação de Pearson para VINHO TINTO
corr_tinto = dados_tinto.corr()
plt.figure(figsize=(14, 7))
plt.subplot(1, 2, 1)
sns.heatmap(corr_tinto, annot=True, annot_kws={"size": 10}, cbar_kws={"shrink": 0.8}, cmap="coolwarm", fmt=".2f")
plt.title("Qualidade Vinho Tinto", fontsize=14)
plt.xticks(rotation=85, fontsize=8)
plt.yticks(fontsize=8)

# Visualização da matriz de correlação de Pearson para Vinho BRANCO
corr_branco = dados_branco.corr()
plt.subplot(1, 2, 2)
sns.heatmap(corr_branco, annot=True, annot_kws={"size": 10}, cbar_kws={"shrink": 0.8}, cmap="coolwarm", fmt=".2f")
plt.title("Qualidade Vinho Branco", fontsize=14)
plt.xticks(rotation=85, fontsize=8)
plt.yticks(fontsize=8)

plt.tight_layout()
plt.show()

#Correlação próxima de 1, indica uma forte correlação positiva, o que significa que quando uma variável aumenta, a outra tende a aumentar também.
#correlação é próxima de -1, indica uma forte correlação negativa, o que significa que quando uma variável aumenta, a outra tende a diminuir.
#correlação é próxima de 0, indica que não há uma relação linear entre as variáveis.

#------------------------------------------CONCLUSÃO------------------------------------------------------------------

#No VINHO TINTO temos as correlações POSITIVAS entre as MAIORES variaveis POSITIVAS: ENXOFRE LIVRE (O,67) , ENXOFRE TOTAL(0,67), ALCOOL (0,48) E QUALIDADE (0,48)
#No VINHO TINTO temos as correlações NEGATIVAS entre as variavies ACIDEZ VOLATIL (-0,55), ACIDO CITRICO (-0,55), DESNSIDADE (-0,34), PH (-0,34)

#No VINHO BRANCO temos as correlações POSITIVAS entre as MAIORES variaveis POSITIVAS: ENXOFRE LIVRE (O,62) , ENXOFRE TOTAL(0,53 A 0,62), ALCOOL (0,44) E QUALIDADE (0,44)
##No VINHO BRANCO temos as correlações NEGATIVAS entre as MAIORES variavies NEGATIVAS: ACIDEZ VOLATIL (-0,15), ACIDO CITRICO (-0,15), DESNSIDADE (-0,9), PH (-0,9)

# %%
# Comparação entre Vinhos Tinto e Branco
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
sns.histplot(dados_tinto['álcool'], kde=True, ax=axes[0, 0],color='maroon')
sns.histplot(dados_branco['álcool'], kde=True, ax=axes[0, 1],color='lightgreen')
sns.histplot(dados_tinto['PH'], kde=True, ax=axes[1, 0],color='maroon')
sns.histplot(dados_branco['PH'], kde=True, ax=axes[1, 1],color='lightgreen')
axes[0, 0].set_title('Vinho Tinto - Teor Alcoolico')
axes[0, 1].set_title('Vinho Branco - Teor Alcoolico')
axes[1, 0].set_title('Vinho Tinto - PH Nível')
axes[1, 1].set_title('Vinho Branco - PH Nível')
plt.tight_layout()
plt.show()

# %%
# Comparação entre Vinhos Tinto e Branco
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
sns.boxplot(x='qualidade', y='álcool', data=dados_tinto, ax=axes[0, 0], color='lightcoral')
sns.boxplot(x='qualidade', y='álcool', data=dados_branco, ax=axes[0, 1], color='lightgreen')
sns.boxplot(x='qualidade', y='PH', data=dados_tinto, ax=axes[1, 0], color='lightcoral')
sns.boxplot(x='qualidade', y='PH', data=dados_branco, ax=axes[1, 1], color='lightgreen')
axes[0, 0].set_title('Vinho Tinto - Qualidade vs. Álcool')
axes[0, 1].set_title('Vinho Branco - Qualidade vs. Álcool')
axes[1, 0].set_title('Vinho Tinto - Qualidade vs. PH')
axes[1, 1].set_title('Vinho Branco - Qualidade vs. PH')
plt.tight_layout()
plt.show()

# %%
#-------------------------------------------------------------CONCLUSÃO------------------------------------------------------------------------------------
#Teor Alcoolico do VINHO TINTO 150 menor que o vinho Branco. VINHO BRTANCO possui teor de alcool maior.
#O teor alcóolico é mais frequente e com maior volume no vinho BRANCO em comparação ao TINTO

#O pico do maior nivel de PH do VINHO TINTO fica em 3.3 atingindo um pico 175
#O pico do maior nivel de PH do VINHO BRANCO fica abaixo de 3.2 atingindo um pico 430
#O PH do vinho BRANCO é menos que do TINTO
